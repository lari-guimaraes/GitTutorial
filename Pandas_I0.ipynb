# %% [markdown]
# <a href="https://colab.research.google.com/github/lari-guimaraes/GitTutorial/blob/main/Pandas_I0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Criando nomes

# %%
import pandas as pd

# %%
nomes_f = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=f")
nomes_f
# Out:
#           nome  regiao      freq  rank sexo
# 0        MARIA       0  11694738     1    F
# 1          ANA       0   3079729     2    F
# 2    FRANCISCA       0    721637     3    F
# 3      ANTONIA       0    588783     4    F
# 4      ADRIANA       0    565621     5    F
# ..         ...     ...       ...   ...  ...
# 195     ROSANE       0     82203   196    F
# 196    IVONETE       0     81878   197    F
# 197    LUCIANE       0     81230   198    F
# 198    ISADORA       0     81100   199    F
# 199      NILZA       0     80128   200    F
#
# [200 rows x 5 columns]

# %%
nomes_m = pd.read_json("https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=200&sexo=m")
nomes_m
# Out:
#           nome  regiao     freq  rank sexo
# 0         JOSE       0  5732508     1    M
# 1         JOAO       0  2971935     2    M
# 2      ANTONIO       0  2567494     3    M
# 3    FRANCISCO       0  1765197     4    M
# 4       CARLOS       0  1483121     5    M
# ..         ...     ...      ...   ...  ...
# 195     WALTER       0    67207   196    M
# 196    ARLINDO       0    66669   197    M
# 197    MICHAEL       0    65736   198    M
# 198     ALVARO       0    65444   199    M
# 199    GEOVANE       0    65435   200    M
#
# [200 rows x 5 columns]

# %%
nomes_f.sample(5)
# Out:
#           nome  regiao    freq  rank sexo
# 50     RAFAELA       0  272718    51    F
# 127      TAINA       0  127613   128    F
# 37   ROSANGELA       0  310226    38    F
# 149     CICERA       0  108197   150    F
# 19     MARIANA       0  381778    20    F

# %%
nomes_m.sample(5)
# Out:
#         nome  regiao    freq  rank sexo
# 187    ELTON       0   71566   188    M
# 173  JAILSON       0   75076   174    M
# 134  ALBERTO       0  108018   135    M
# 147  ALISSON       0   94270   148    M
# 57      IGOR       0  264732    58    M

# %%
print('Quantidade de nomes:' + str(len(nomes_f) + len(nomes_m)))
# Out:
# Quantidade de nomes:400

# %%
frames = [nomes_f, nomes_m]

# %%
nomes = pd.concat(frames)['nome'].to_frame()

# %%
nomes
# Out:
#           nome
# 0        MARIA
# 1          ANA
# 2    FRANCISCA
# 3      ANTONIA
# 4      ADRIANA
# ..         ...
# 195     WALTER
# 196    ARLINDO
# 197    MICHAEL
# 198     ALVARO
# 199    GEOVANE
#
# [400 rows x 1 columns]

# %% [markdown]
# # Incluindo ID dos alunos

# %%
import numpy as np

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 400

# %%
nomes['id_aluno'] = np.random.permutation(total_alunos) + 1

# %%
dominios = ['@dominiodoemail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)
nomes
# Out:
#           nome  id_aluno                 dominio
# 0        MARIA       219  @dominiodoemail.com.br
# 1          ANA        56     @servicodoemail.com
# 2    FRANCISCA       146     @servicodoemail.com
# 3      ANTONIA       216  @dominiodoemail.com.br
# 4      ADRIANA       377     @servicodoemail.com
# ..         ...       ...                     ...
# 195     WALTER       303  @dominiodoemail.com.br
# 196    ARLINDO       279     @servicodoemail.com
# 197    MICHAEL       180  @dominiodoemail.com.br
# 198     ALVARO       202  @dominiodoemail.com.br
# 199    GEOVANE       158     @servicodoemail.com
#
# [400 rows x 3 columns]

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes.sample(5)
# Out:
#           nome  ...                            email
# 84    SEVERINO  ...   severino@dominiodoemail.com.br
# 0         JOSE  ...          jose@servicodoemail.com
# 179       IAGO  ...       iago@dominiodoemail.com.br
# 10      SANDRA  ...     sandra@dominiodoemail.com.br
# 171  TERESINHA  ...  teresinha@dominiodoemail.com.br
#
# [5 rows x 4 columns]

# %%
# Criando a tabela Curso

# %%
# !pip3 install html5lib
# !pip3 install lxml

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
type(cursos)
# Out:
# list

# %%
cursos[0]
# Out:
#                           Nome do curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %%
cursos = cursos[0]

# %%
cursos.head(5)
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %% [markdown]
# # Alterando o index de curso

# %%
cursos = cursos.rename(columns={'Nome do curso' : 'nome_do_curso'})
cursos.head(5)
# Out:
#            nome_do_curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
cursos['id'] = cursos.index + 1

# %%
cursos.head(5)
# Out:
#            nome_do_curso  id
# 0  Lógica de programação   1
# 1          Java para Web   2
# 2            C# para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos = cursos.set_index('id')

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python
